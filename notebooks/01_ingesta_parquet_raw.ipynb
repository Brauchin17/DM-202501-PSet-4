# %%
import os
import argparse
import psycopg2
import pandas as pd
from dotenv import load_dotenv
from datetime import datetime
import time
from pyspark.sql import SparkSession
import requests
import tempfile

# %%
load_dotenv() 

PG_HOST = os.getenv("PG_HOST")
PG_PORT = os.getenv("PG_PORT")
PG_DB = os.getenv("PG_DB")
PG_USER = os.getenv("PG_USER")
PG_PASSWORD = os.getenv("PG_PASSWORD")
PG_SCHEMA = os.getenv("PG_SCHEMA_RAW")

# %%
# ingesta de datos de parquet a postgres

spark = SparkSession.builder \
    .appName("IngestaParquetPostgres") \
    .config("spark.jars.packages", "org.postgresql:postgresql:42.2.18") \
    .getOrCreate()

# %%
pgOptions = {
    "url": f"jdbc:postgresql://{os.getenv('PG_HOST', 'postgres-warehouse')}:{os.getenv('PG_PORT', '5432')}/{os.getenv('PG_DB', 'warehouse_db')}",
    "user": os.getenv("PG_USER", "postgres"),
    "password": os.getenv("PG_PASSWORD", "postgres"),
    "driver": "org.postgresql.Driver"
}

# %%
years = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
services = ['yellow', 'green']

for service in services:
    if service == 'yellow':
        ordered_cols = [
            "VENDORID", "TPEP_PICKUP_DATETIME", "TPEP_DROPOFF_DATETIME",
            "PASSENGER_COUNT", "TRIP_DISTANCE", "RATECODEID",
            "STORE_AND_FWD_FLAG", "PULOCATIONID", "DOLOCATIONID",
            "PAYMENT_TYPE", "FARE_AMOUNT", "EXTRA", "MTA_TAX",
            "TIP_AMOUNT", "TOLLS_AMOUNT", "IMPROVEMENT_SURCHARGE",
            "TOTAL_AMOUNT", "CONGESTION_SURCHARGE", "AIRPORT_FEE",
            "CBD_CONGESTION_FEE",
            "RUN_ID", "SERVICE_TYPE", "SOURCE_YEAR", "SOURCE_MONTH",
            "INGESTED_AT_UTC", "SOURCE_PATH"
        ]
    else:
        ordered_cols = [
            "VENDORID", "LPEP_PICKUP_DATETIME", "LPEP_DROPOFF_DATETIME",
            "STORE_AND_FWD_FLAG", "RATECODEID",
            "PULOCATIONID", "DOLOCATIONID", "PASSENGER_COUNT", "TRIP_DISTANCE",
            "FARE_AMOUNT", "EXTRA", "MTA_TAX", "TIP_AMOUNT", "TOLLS_AMOUNT",
            "EHAIL_FEE", "IMPROVEMENT_SURCHARGE", "TOTAL_AMOUNT",
            "PAYMENT_TYPE", "TRIP_TYPE", "CONGESTION_SURCHARGE",
            "CBD_CONGESTION_FEE",
            "RUN_ID", "SERVICE_TYPE", "SOURCE_YEAR", "SOURCE_MONTH",
            "INGESTED_AT_UTC", "SOURCE_PATH"
        ]   
    for year in years:
        if year == '2025':
            months = ['01', '02', '03', '04', '05', '06', '07', '08']
        for month in months:
            if service == 'yellow':
                timestamp_columns = ['TPEP_PICKUP_DATETIME', 'TPEP_DROPOFF_DATETIME']
            else:
                timestamp_columns = ['LPEP_PICKUP_DATETIME', 'LPEP_DROPOFF_DATETIME']
            for attempt in range(3):  # Intentar hasta 3 veces en caso de fallo
                try: 
                    url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/{service}_tripdata_{year}-{month}.parquet"
                    # try to access the url, si no existe volver a intentar
                    for attempt in range(5):
                        response = requests.head(url)
                        if response.status_code != 200:
                            print(f"No existe: {url}")
                            continue
                        print(f"Procesando {service}: {year}-{month}")
                        break

                    # Descargar archivo temporal
                    tmp_file = tempfile.NamedTemporaryFile(delete=False, suffix=".parquet")
                    tmp_path = tmp_file.name
                    tmp_file.close()
                    r = requests.get(url)
                    with open(tmp_path, "wb") as f:
                        f.write(r.content)

                    # Leer archivo parquet
                    df = spark.read.parquet(tmp_path)
                    print(f"Archivo {url} cargado en DataFrame")

                    # Crear run_id
                    run_id = f"run_{year}_{month}"

                    # Agregar metadatos
                    df = (
                        df.withColumn("RUN_ID", F.lit(run_id))
                        .withColumn("SERVICE_TYPE", F.lit(service))
                        .withColumn("SOURCE_YEAR", F.lit(int(year)))
                        .withColumn("SOURCE_MONTH", F.lit(int(month)))
                        .withColumn("INGESTED_AT_UTC", F.current_timestamp())
                        .withColumn("SOURCE_PATH", F.lit(url))
                    )

                    # Normalizar columnas
                    df = df.toDF(*[c.upper() for c in df.columns])

                    # Asegurar columnas timestamp
                    for col_name in timestamp_columns:
                        if col_name in df.columns:
                            df = df.withColumn(col_name, F.col(col_name).cast("timestamp"))

                    # Columna nueva si no existe
                    if "CBD_CONGESTION_FEE" not in df.columns:
                        df = df.withColumn("CBD_CONGESTION_FEE", F.lit(None).cast(T.DoubleType()))

                    table_name = f"{PG_SCHEMA}.{service.upper()}_TRIPS"


                    # Reordenar columnas
                    df = df.select([c for c in ordered_cols if c in df.columns])

                    # indempotencia, verificar si el run_id ya existe en la tabla con sparksql
                    query_check = f"SELECT COUNT(1) FROM {table_name} WHERE RUN_ID = {run_id}"
                    existing_count = spark.read \
                        .format("jdbc") \
                        .options(**pgOptions) \
                        .option("dbtable", f"({query_check}) AS check_table") \
                        .load() \
                        .collect()[0][0]
                    if existing_count > 0:
                        print(f"Datos para {service} {year}-{month} ya existen en la tabla. Saltando...")
                        os.remove(tmp_path)
                        break  # Salir del bucle de reintentos si ya existe
            
                    df.write \
                        .format("jdbc") \
                        .options(**pgOptions) \
                        .option("dbtable", table_name) \
                        .mode("append") \
                        .save()

                    print(f"Datos de {service} para {year}-{month} cargados en PostgreSQL")

                    os.remove(tmp_path)
                    break  # Salir del bucle de reintentos si tiene éxito
                except Exception as e:
                    print(f"Error al procesar {service} {year}-{month}: {e}")
                    if attempt < 2:
                        print("Reintentando...")
                        time.sleep(10 * (attempt + 1))  # Esperar antes de reintentar
                    else:
                        print("Máximo de intentos alcanzado. Pasando al siguiente.")
                        os.remove(tmp_path)
                        continue
# Out:
# Procesando yellow: 2015-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-01.parquet cargado en DataFrame
# Datos de yellow para 2015-01 cargados en PostgreSQL
# Procesando yellow: 2015-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-02.parquet cargado en DataFrame
# Datos de yellow para 2015-02 cargados en PostgreSQL
# Procesando yellow: 2015-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-03.parquet cargado en DataFrame
# Datos de yellow para 2015-03 cargados en PostgreSQL
# Procesando yellow: 2015-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-04.parquet cargado en DataFrame
# Datos de yellow para 2015-04 cargados en PostgreSQL
# Procesando yellow: 2015-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-05.parquet cargado en DataFrame
# Datos de yellow para 2015-05 cargados en PostgreSQL
# Procesando yellow: 2015-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-06.parquet cargado en DataFrame
# Datos de yellow para 2015-06 cargados en PostgreSQL
# Procesando yellow: 2015-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-07.parquet cargado en DataFrame
# Datos de yellow para 2015-07 cargados en PostgreSQL
# Procesando yellow: 2015-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-08.parquet cargado en DataFrame
# Datos de yellow para 2015-08 cargados en PostgreSQL
# Procesando yellow: 2015-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-09.parquet cargado en DataFrame
# Datos de yellow para 2015-09 cargados en PostgreSQL
# Procesando yellow: 2015-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-10.parquet cargado en DataFrame
# Datos de yellow para 2015-10 cargados en PostgreSQL
# Procesando yellow: 2015-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-11.parquet cargado en DataFrame
# Datos de yellow para 2015-11 cargados en PostgreSQL
# Procesando yellow: 2015-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2015-12.parquet cargado en DataFrame
# Datos de yellow para 2015-12 cargados en PostgreSQL
# Procesando yellow: 2016-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-01.parquet cargado en DataFrame
# Datos de yellow para 2016-01 cargados en PostgreSQL
# Procesando yellow: 2016-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-02.parquet cargado en DataFrame
# Datos de yellow para 2016-02 cargados en PostgreSQL
# Procesando yellow: 2016-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-03.parquet cargado en DataFrame
# Datos de yellow para 2016-03 cargados en PostgreSQL
# Procesando yellow: 2016-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-04.parquet cargado en DataFrame
# Datos de yellow para 2016-04 cargados en PostgreSQL
# Procesando yellow: 2016-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-05.parquet cargado en DataFrame
# Datos de yellow para 2016-05 cargados en PostgreSQL
# Procesando yellow: 2016-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-06.parquet cargado en DataFrame
# Datos de yellow para 2016-06 cargados en PostgreSQL
# Procesando yellow: 2016-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-07.parquet cargado en DataFrame
# Datos de yellow para 2016-07 cargados en PostgreSQL
# Procesando yellow: 2016-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-08.parquet cargado en DataFrame
# Datos de yellow para 2016-08 cargados en PostgreSQL
# Procesando yellow: 2016-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-09.parquet cargado en DataFrame
# Datos de yellow para 2016-09 cargados en PostgreSQL
# Procesando yellow: 2016-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-10.parquet cargado en DataFrame
# Datos de yellow para 2016-10 cargados en PostgreSQL
# Procesando yellow: 2016-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-11.parquet cargado en DataFrame
# Datos de yellow para 2016-11 cargados en PostgreSQL
# Procesando yellow: 2016-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2016-12.parquet cargado en DataFrame
# Datos de yellow para 2016-12 cargados en PostgreSQL
# Procesando yellow: 2017-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-01.parquet cargado en DataFrame
# Datos de yellow para 2017-01 cargados en PostgreSQL
# Procesando yellow: 2017-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-02.parquet cargado en DataFrame
# Datos de yellow para 2017-02 cargados en PostgreSQL
# Procesando yellow: 2017-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-03.parquet cargado en DataFrame
# Datos de yellow para 2017-03 cargados en PostgreSQL
# Procesando yellow: 2017-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-04.parquet cargado en DataFrame
# Datos de yellow para 2017-04 cargados en PostgreSQL
# Procesando yellow: 2017-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-05.parquet cargado en DataFrame
# Datos de yellow para 2017-05 cargados en PostgreSQL
# Procesando yellow: 2017-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-06.parquet cargado en DataFrame
# Datos de yellow para 2017-06 cargados en PostgreSQL
# Procesando yellow: 2017-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-07.parquet cargado en DataFrame
# Datos de yellow para 2017-07 cargados en PostgreSQL
# Procesando yellow: 2017-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-08.parquet cargado en DataFrame
# Datos de yellow para 2017-08 cargados en PostgreSQL
# Procesando yellow: 2017-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-09.parquet cargado en DataFrame
# Datos de yellow para 2017-09 cargados en PostgreSQL
# Procesando yellow: 2017-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-10.parquet cargado en DataFrame
# Datos de yellow para 2017-10 cargados en PostgreSQL
# Procesando yellow: 2017-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-11.parquet cargado en DataFrame
# Datos de yellow para 2017-11 cargados en PostgreSQL
# Procesando yellow: 2017-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2017-12.parquet cargado en DataFrame
# Datos de yellow para 2017-12 cargados en PostgreSQL
# Procesando yellow: 2018-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-01.parquet cargado en DataFrame
# Datos de yellow para 2018-01 cargados en PostgreSQL
# Procesando yellow: 2018-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-02.parquet cargado en DataFrame
# Datos de yellow para 2018-02 cargados en PostgreSQL
# Procesando yellow: 2018-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-03.parquet cargado en DataFrame
# Datos de yellow para 2018-03 cargados en PostgreSQL
# Procesando yellow: 2018-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-04.parquet cargado en DataFrame
# Datos de yellow para 2018-04 cargados en PostgreSQL
# Procesando yellow: 2018-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-05.parquet cargado en DataFrame
# Datos de yellow para 2018-05 cargados en PostgreSQL
# Procesando yellow: 2018-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-06.parquet cargado en DataFrame
# Datos de yellow para 2018-06 cargados en PostgreSQL
# Procesando yellow: 2018-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-07.parquet cargado en DataFrame
# Datos de yellow para 2018-07 cargados en PostgreSQL
# Procesando yellow: 2018-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-08.parquet cargado en DataFrame
# Datos de yellow para 2018-08 cargados en PostgreSQL
# Procesando yellow: 2018-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-09.parquet cargado en DataFrame
# Datos de yellow para 2018-09 cargados en PostgreSQL
# Procesando yellow: 2018-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-10.parquet cargado en DataFrame
# Datos de yellow para 2018-10 cargados en PostgreSQL
# Procesando yellow: 2018-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-11.parquet cargado en DataFrame
# Datos de yellow para 2018-11 cargados en PostgreSQL
# Procesando yellow: 2018-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2018-12.parquet cargado en DataFrame
# Datos de yellow para 2018-12 cargados en PostgreSQL
# Procesando yellow: 2019-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-01.parquet cargado en DataFrame
# Datos de yellow para 2019-01 cargados en PostgreSQL
# Procesando yellow: 2019-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-02.parquet cargado en DataFrame
# Datos de yellow para 2019-02 cargados en PostgreSQL
# Procesando yellow: 2019-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-03.parquet cargado en DataFrame
# Datos de yellow para 2019-03 cargados en PostgreSQL
# Procesando yellow: 2019-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-04.parquet cargado en DataFrame
# Datos de yellow para 2019-04 cargados en PostgreSQL
# Procesando yellow: 2019-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-05.parquet cargado en DataFrame
# Datos de yellow para 2019-05 cargados en PostgreSQL
# Procesando yellow: 2019-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-06.parquet cargado en DataFrame
# Datos de yellow para 2019-06 cargados en PostgreSQL
# Procesando yellow: 2019-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-07.parquet cargado en DataFrame
# Datos de yellow para 2019-07 cargados en PostgreSQL
# Procesando yellow: 2019-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-08.parquet cargado en DataFrame
# Datos de yellow para 2019-08 cargados en PostgreSQL
# Procesando yellow: 2019-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-09.parquet cargado en DataFrame
# Datos de yellow para 2019-09 cargados en PostgreSQL
# Procesando yellow: 2019-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-10.parquet cargado en DataFrame
# Datos de yellow para 2019-10 cargados en PostgreSQL
# Procesando yellow: 2019-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-11.parquet cargado en DataFrame
# Datos de yellow para 2019-11 cargados en PostgreSQL
# Procesando yellow: 2019-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2019-12.parquet cargado en DataFrame
# Datos de yellow para 2019-12 cargados en PostgreSQL
# Procesando yellow: 2020-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-01.parquet cargado en DataFrame
# Datos de yellow para 2020-01 cargados en PostgreSQL
# Procesando yellow: 2020-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-02.parquet cargado en DataFrame
# Datos de yellow para 2020-02 cargados en PostgreSQL
# Procesando yellow: 2020-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-03.parquet cargado en DataFrame
# Datos de yellow para 2020-03 cargados en PostgreSQL
# Procesando yellow: 2020-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-04.parquet cargado en DataFrame
# Datos de yellow para 2020-04 cargados en PostgreSQL
# Procesando yellow: 2020-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-05.parquet cargado en DataFrame
# Datos de yellow para 2020-05 cargados en PostgreSQL
# Procesando yellow: 2020-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-06.parquet cargado en DataFrame
# Datos de yellow para 2020-06 cargados en PostgreSQL
# Procesando yellow: 2020-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-07.parquet cargado en DataFrame
# Datos de yellow para 2020-07 cargados en PostgreSQL
# Procesando yellow: 2020-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-08.parquet cargado en DataFrame
# Datos de yellow para 2020-08 cargados en PostgreSQL
# Procesando yellow: 2020-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-09.parquet cargado en DataFrame
# Datos de yellow para 2020-09 cargados en PostgreSQL
# Procesando yellow: 2020-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-10.parquet cargado en DataFrame
# Datos de yellow para 2020-10 cargados en PostgreSQL
# Procesando yellow: 2020-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-11.parquet cargado en DataFrame
# Datos de yellow para 2020-11 cargados en PostgreSQL
# Procesando yellow: 2020-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2020-12.parquet cargado en DataFrame
# Datos de yellow para 2020-12 cargados en PostgreSQL
# Procesando yellow: 2021-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet cargado en DataFrame
# Datos de yellow para 2021-01 cargados en PostgreSQL
# Procesando yellow: 2021-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-02.parquet cargado en DataFrame
# Datos de yellow para 2021-02 cargados en PostgreSQL
# Procesando yellow: 2021-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-03.parquet cargado en DataFrame
# Datos de yellow para 2021-03 cargados en PostgreSQL
# Procesando yellow: 2021-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-04.parquet cargado en DataFrame
# Datos de yellow para 2021-04 cargados en PostgreSQL
# Procesando yellow: 2021-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-05.parquet cargado en DataFrame
# Datos de yellow para 2021-05 cargados en PostgreSQL
# Procesando yellow: 2021-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-06.parquet cargado en DataFrame
# Datos de yellow para 2021-06 cargados en PostgreSQL
# Procesando yellow: 2021-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-07.parquet cargado en DataFrame
# Datos de yellow para 2021-07 cargados en PostgreSQL
# Procesando yellow: 2021-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-08.parquet cargado en DataFrame
# Datos de yellow para 2021-08 cargados en PostgreSQL
# Procesando yellow: 2021-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-09.parquet cargado en DataFrame
# Datos de yellow para 2021-09 cargados en PostgreSQL
# Procesando yellow: 2021-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-10.parquet cargado en DataFrame
# Datos de yellow para 2021-10 cargados en PostgreSQL
# Procesando yellow: 2021-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-11.parquet cargado en DataFrame
# Datos de yellow para 2021-11 cargados en PostgreSQL
# Procesando yellow: 2021-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-12.parquet cargado en DataFrame
# Datos de yellow para 2021-12 cargados en PostgreSQL
# Procesando yellow: 2022-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-01.parquet cargado en DataFrame
# Datos de yellow para 2022-01 cargados en PostgreSQL
# Procesando yellow: 2022-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-02.parquet cargado en DataFrame
# Datos de yellow para 2022-02 cargados en PostgreSQL
# Procesando yellow: 2022-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-03.parquet cargado en DataFrame
# Datos de yellow para 2022-03 cargados en PostgreSQL
# Procesando yellow: 2022-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-04.parquet cargado en DataFrame
# Datos de yellow para 2022-04 cargados en PostgreSQL
# Procesando yellow: 2022-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-05.parquet cargado en DataFrame
# Datos de yellow para 2022-05 cargados en PostgreSQL
# Procesando yellow: 2022-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-06.parquet cargado en DataFrame
# Datos de yellow para 2022-06 cargados en PostgreSQL
# Procesando yellow: 2022-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-07.parquet cargado en DataFrame
# Datos de yellow para 2022-07 cargados en PostgreSQL
# Procesando yellow: 2022-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-08.parquet cargado en DataFrame
# Datos de yellow para 2022-08 cargados en PostgreSQL
# Procesando yellow: 2022-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-09.parquet cargado en DataFrame
# Datos de yellow para 2022-09 cargados en PostgreSQL
# Procesando yellow: 2022-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-10.parquet cargado en DataFrame
# Datos de yellow para 2022-10 cargados en PostgreSQL
# Procesando yellow: 2022-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-11.parquet cargado en DataFrame
# Datos de yellow para 2022-11 cargados en PostgreSQL
# Procesando yellow: 2022-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-12.parquet cargado en DataFrame
# Datos de yellow para 2022-12 cargados en PostgreSQL
# Procesando yellow: 2023-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet cargado en DataFrame
# Datos de yellow para 2023-01 cargados en PostgreSQL
# Procesando yellow: 2023-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet cargado en DataFrame
# Datos de yellow para 2023-02 cargados en PostgreSQL
# Procesando yellow: 2023-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet cargado en DataFrame
# Datos de yellow para 2023-03 cargados en PostgreSQL
# Procesando yellow: 2023-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-04.parquet cargado en DataFrame
# Datos de yellow para 2023-04 cargados en PostgreSQL
# Procesando yellow: 2023-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-05.parquet cargado en DataFrame
# Datos de yellow para 2023-05 cargados en PostgreSQL
# Procesando yellow: 2023-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-06.parquet cargado en DataFrame
# Datos de yellow para 2023-06 cargados en PostgreSQL
# Procesando yellow: 2023-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-07.parquet cargado en DataFrame
# Datos de yellow para 2023-07 cargados en PostgreSQL
# Procesando yellow: 2023-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-08.parquet cargado en DataFrame
# Datos de yellow para 2023-08 cargados en PostgreSQL
# Procesando yellow: 2023-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-09.parquet cargado en DataFrame
# Datos de yellow para 2023-09 cargados en PostgreSQL
# Procesando yellow: 2023-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-10.parquet cargado en DataFrame
# Datos de yellow para 2023-10 cargados en PostgreSQL
# Procesando yellow: 2023-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-11.parquet cargado en DataFrame
# Datos de yellow para 2023-11 cargados en PostgreSQL
# Procesando yellow: 2023-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-12.parquet cargado en DataFrame
# Datos de yellow para 2023-12 cargados en PostgreSQL
# Procesando yellow: 2024-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet cargado en DataFrame
# Datos de yellow para 2024-01 cargados en PostgreSQL
# Procesando yellow: 2024-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-02.parquet cargado en DataFrame
# Datos de yellow para 2024-02 cargados en PostgreSQL
# Procesando yellow: 2024-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-03.parquet cargado en DataFrame
# Datos de yellow para 2024-03 cargados en PostgreSQL
# Procesando yellow: 2024-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-04.parquet cargado en DataFrame
# Datos de yellow para 2024-04 cargados en PostgreSQL
# Procesando yellow: 2024-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-05.parquet cargado en DataFrame
# Datos de yellow para 2024-05 cargados en PostgreSQL
# Procesando yellow: 2024-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-06.parquet cargado en DataFrame
# Datos de yellow para 2024-06 cargados en PostgreSQL
# Procesando yellow: 2024-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-07.parquet cargado en DataFrame
# Datos de yellow para 2024-07 cargados en PostgreSQL
# Procesando yellow: 2024-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-08.parquet cargado en DataFrame
# Datos de yellow para 2024-08 cargados en PostgreSQL
# Procesando yellow: 2024-09
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-09.parquet cargado en DataFrame
# Datos de yellow para 2024-09 cargados en PostgreSQL
# Procesando yellow: 2024-10
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-10.parquet cargado en DataFrame
# Datos de yellow para 2024-10 cargados en PostgreSQL
# Procesando yellow: 2024-11
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-11.parquet cargado en DataFrame
# Datos de yellow para 2024-11 cargados en PostgreSQL
# Procesando yellow: 2024-12
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-12.parquet cargado en DataFrame
# Datos de yellow para 2024-12 cargados en PostgreSQL
# Procesando yellow: 2025-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-01.parquet cargado en DataFrame
# Datos de yellow para 2025-01 cargados en PostgreSQL
# Procesando yellow: 2025-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-02.parquet cargado en DataFrame
# Datos de yellow para 2025-02 cargados en PostgreSQL
# Procesando yellow: 2025-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-03.parquet cargado en DataFrame
# Datos de yellow para 2025-03 cargados en PostgreSQL
# Procesando yellow: 2025-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-04.parquet cargado en DataFrame
# Datos de yellow para 2025-04 cargados en PostgreSQL
# Procesando yellow: 2025-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-05.parquet cargado en DataFrame
# Datos de yellow para 2025-05 cargados en PostgreSQL
# Procesando yellow: 2025-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-06.parquet cargado en DataFrame
# Datos de yellow para 2025-06 cargados en PostgreSQL
# Procesando yellow: 2025-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-07.parquet cargado en DataFrame
# Datos de yellow para 2025-07 cargados en PostgreSQL
# Procesando yellow: 2025-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-08.parquet cargado en DataFrame
# Datos de yellow para 2025-08 cargados en PostgreSQL
# Procesando green: 2015-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-01.parquet cargado en DataFrame
# Datos de green para 2015-01 cargados en PostgreSQL
# Procesando green: 2015-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-02.parquet cargado en DataFrame
# Datos de green para 2015-02 cargados en PostgreSQL
# Procesando green: 2015-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-03.parquet cargado en DataFrame
# Datos de green para 2015-03 cargados en PostgreSQL
# Procesando green: 2015-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-04.parquet cargado en DataFrame
# Datos de green para 2015-04 cargados en PostgreSQL
# Procesando green: 2015-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-05.parquet cargado en DataFrame
# Datos de green para 2015-05 cargados en PostgreSQL
# Procesando green: 2015-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-06.parquet cargado en DataFrame
# Datos de green para 2015-06 cargados en PostgreSQL
# Procesando green: 2015-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-07.parquet cargado en DataFrame
# Datos de green para 2015-07 cargados en PostgreSQL
# Procesando green: 2015-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2015-08.parquet cargado en DataFrame
# Datos de green para 2015-08 cargados en PostgreSQL
# Procesando green: 2016-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-01.parquet cargado en DataFrame
# Datos de green para 2016-01 cargados en PostgreSQL
# Procesando green: 2016-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-02.parquet cargado en DataFrame
# Datos de green para 2016-02 cargados en PostgreSQL
# Procesando green: 2016-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-03.parquet cargado en DataFrame
# Datos de green para 2016-03 cargados en PostgreSQL
# Procesando green: 2016-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-04.parquet cargado en DataFrame
# Datos de green para 2016-04 cargados en PostgreSQL
# Procesando green: 2016-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-05.parquet cargado en DataFrame
# Datos de green para 2016-05 cargados en PostgreSQL
# Procesando green: 2016-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-06.parquet cargado en DataFrame
# Datos de green para 2016-06 cargados en PostgreSQL
# Procesando green: 2016-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-07.parquet cargado en DataFrame
# Datos de green para 2016-07 cargados en PostgreSQL
# Procesando green: 2016-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2016-08.parquet cargado en DataFrame
# Datos de green para 2016-08 cargados en PostgreSQL
# Procesando green: 2017-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-01.parquet cargado en DataFrame
# Datos de green para 2017-01 cargados en PostgreSQL
# Procesando green: 2017-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-02.parquet cargado en DataFrame
# Datos de green para 2017-02 cargados en PostgreSQL
# Procesando green: 2017-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-03.parquet cargado en DataFrame
# Datos de green para 2017-03 cargados en PostgreSQL
# Procesando green: 2017-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-04.parquet cargado en DataFrame
# Datos de green para 2017-04 cargados en PostgreSQL
# Procesando green: 2017-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-05.parquet cargado en DataFrame
# Datos de green para 2017-05 cargados en PostgreSQL
# Procesando green: 2017-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-06.parquet cargado en DataFrame
# Datos de green para 2017-06 cargados en PostgreSQL
# Procesando green: 2017-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-07.parquet cargado en DataFrame
# Datos de green para 2017-07 cargados en PostgreSQL
# Procesando green: 2017-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2017-08.parquet cargado en DataFrame
# Datos de green para 2017-08 cargados en PostgreSQL
# Procesando green: 2018-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-01.parquet cargado en DataFrame
# Datos de green para 2018-01 cargados en PostgreSQL
# Procesando green: 2018-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-02.parquet cargado en DataFrame
# Datos de green para 2018-02 cargados en PostgreSQL
# Procesando green: 2018-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-03.parquet cargado en DataFrame
# Datos de green para 2018-03 cargados en PostgreSQL
# Procesando green: 2018-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-04.parquet cargado en DataFrame
# Datos de green para 2018-04 cargados en PostgreSQL
# Procesando green: 2018-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-05.parquet cargado en DataFrame
# Datos de green para 2018-05 cargados en PostgreSQL
# Procesando green: 2018-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-06.parquet cargado en DataFrame
# Datos de green para 2018-06 cargados en PostgreSQL
# Procesando green: 2018-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-07.parquet cargado en DataFrame
# Datos de green para 2018-07 cargados en PostgreSQL
# Procesando green: 2018-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2018-08.parquet cargado en DataFrame
# Datos de green para 2018-08 cargados en PostgreSQL
# Procesando green: 2019-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-01.parquet cargado en DataFrame
# Datos de green para 2019-01 cargados en PostgreSQL
# Procesando green: 2019-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-02.parquet cargado en DataFrame
# Datos de green para 2019-02 cargados en PostgreSQL
# Procesando green: 2019-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-03.parquet cargado en DataFrame
# Datos de green para 2019-03 cargados en PostgreSQL
# Procesando green: 2019-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-04.parquet cargado en DataFrame
# Datos de green para 2019-04 cargados en PostgreSQL
# Procesando green: 2019-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-05.parquet cargado en DataFrame
# Datos de green para 2019-05 cargados en PostgreSQL
# Procesando green: 2019-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-06.parquet cargado en DataFrame
# Datos de green para 2019-06 cargados en PostgreSQL
# Procesando green: 2019-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-07.parquet cargado en DataFrame
# Datos de green para 2019-07 cargados en PostgreSQL
# Procesando green: 2019-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-08.parquet cargado en DataFrame
# Datos de green para 2019-08 cargados en PostgreSQL
# Procesando green: 2020-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-01.parquet cargado en DataFrame
# Datos de green para 2020-01 cargados en PostgreSQL
# Procesando green: 2020-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-02.parquet cargado en DataFrame
# Datos de green para 2020-02 cargados en PostgreSQL
# Procesando green: 2020-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-03.parquet cargado en DataFrame
# Datos de green para 2020-03 cargados en PostgreSQL
# Procesando green: 2020-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-04.parquet cargado en DataFrame
# Datos de green para 2020-04 cargados en PostgreSQL
# Procesando green: 2020-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-05.parquet cargado en DataFrame
# Datos de green para 2020-05 cargados en PostgreSQL
# Procesando green: 2020-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-06.parquet cargado en DataFrame
# Datos de green para 2020-06 cargados en PostgreSQL
# Procesando green: 2020-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-07.parquet cargado en DataFrame
# Datos de green para 2020-07 cargados en PostgreSQL
# Procesando green: 2020-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2020-08.parquet cargado en DataFrame
# Datos de green para 2020-08 cargados en PostgreSQL
# Procesando green: 2021-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet cargado en DataFrame
# Datos de green para 2021-01 cargados en PostgreSQL
# Procesando green: 2021-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet cargado en DataFrame
# Datos de green para 2021-02 cargados en PostgreSQL
# Procesando green: 2021-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-03.parquet cargado en DataFrame
# Datos de green para 2021-03 cargados en PostgreSQL
# Procesando green: 2021-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-04.parquet cargado en DataFrame
# Datos de green para 2021-04 cargados en PostgreSQL
# Procesando green: 2021-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-05.parquet cargado en DataFrame
# Datos de green para 2021-05 cargados en PostgreSQL
# Procesando green: 2021-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-06.parquet cargado en DataFrame
# Datos de green para 2021-06 cargados en PostgreSQL
# Procesando green: 2021-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-07.parquet cargado en DataFrame
# Datos de green para 2021-07 cargados en PostgreSQL
# Procesando green: 2021-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-08.parquet cargado en DataFrame
# Datos de green para 2021-08 cargados en PostgreSQL
# Procesando green: 2022-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-01.parquet cargado en DataFrame
# Datos de green para 2022-01 cargados en PostgreSQL
# Procesando green: 2022-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-02.parquet cargado en DataFrame
# Datos de green para 2022-02 cargados en PostgreSQL
# Procesando green: 2022-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-03.parquet cargado en DataFrame
# Datos de green para 2022-03 cargados en PostgreSQL
# Procesando green: 2022-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-04.parquet cargado en DataFrame
# Datos de green para 2022-04 cargados en PostgreSQL
# Procesando green: 2022-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-05.parquet cargado en DataFrame
# Datos de green para 2022-05 cargados en PostgreSQL
# Procesando green: 2022-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-06.parquet cargado en DataFrame
# Datos de green para 2022-06 cargados en PostgreSQL
# Procesando green: 2022-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-07.parquet cargado en DataFrame
# Datos de green para 2022-07 cargados en PostgreSQL
# Procesando green: 2022-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-08.parquet cargado en DataFrame
# Datos de green para 2022-08 cargados en PostgreSQL
# Procesando green: 2023-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-01.parquet cargado en DataFrame
# Datos de green para 2023-01 cargados en PostgreSQL
# Procesando green: 2023-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-02.parquet cargado en DataFrame
# Datos de green para 2023-02 cargados en PostgreSQL
# Procesando green: 2023-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-03.parquet cargado en DataFrame
# Datos de green para 2023-03 cargados en PostgreSQL
# Procesando green: 2023-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-04.parquet cargado en DataFrame
# Datos de green para 2023-04 cargados en PostgreSQL
# Procesando green: 2023-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-05.parquet cargado en DataFrame
# Datos de green para 2023-05 cargados en PostgreSQL
# Procesando green: 2023-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-06.parquet cargado en DataFrame
# Datos de green para 2023-06 cargados en PostgreSQL
# Procesando green: 2023-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-07.parquet cargado en DataFrame
# Datos de green para 2023-07 cargados en PostgreSQL
# Procesando green: 2023-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-08.parquet cargado en DataFrame
# Datos de green para 2023-08 cargados en PostgreSQL
# Procesando green: 2024-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet cargado en DataFrame
# Datos de green para 2024-01 cargados en PostgreSQL
# Procesando green: 2024-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-02.parquet cargado en DataFrame
# Datos de green para 2024-02 cargados en PostgreSQL
# Procesando green: 2024-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet cargado en DataFrame
# Datos de green para 2024-03 cargados en PostgreSQL
# Procesando green: 2024-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-04.parquet cargado en DataFrame
# Datos de green para 2024-04 cargados en PostgreSQL
# Procesando green: 2024-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-05.parquet cargado en DataFrame
# Datos de green para 2024-05 cargados en PostgreSQL
# Procesando green: 2024-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-06.parquet cargado en DataFrame
# Datos de green para 2024-06 cargados en PostgreSQL
# Procesando green: 2024-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-07.parquet cargado en DataFrame
# Datos de green para 2024-07 cargados en PostgreSQL
# Procesando green: 2024-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-08.parquet cargado en DataFrame
# Datos de green para 2024-08 cargados en PostgreSQL
# Procesando green: 2025-01
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-01.parquet cargado en DataFrame
# Datos de green para 2025-01 cargados en PostgreSQL
# Procesando green: 2025-02
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-02.parquet cargado en DataFrame
# Datos de green para 2025-02 cargados en PostgreSQL
# Procesando green: 2025-03
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-03.parquet cargado en DataFrame
# Datos de green para 2025-03 cargados en PostgreSQL
# Procesando green: 2025-04
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-04.parquet cargado en DataFrame
# Datos de green para 2025-04 cargados en PostgreSQL
# Procesando green: 2025-05
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-05.parquet cargado en DataFrame
# Datos de green para 2025-05 cargados en PostgreSQL
# Procesando green: 2025-06
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-06.parquet cargado en DataFrame
# Datos de green para 2025-06 cargados en PostgreSQL
# Procesando green: 2025-07
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-07.parquet cargado en DataFrame
# Datos de green para 2025-07 cargados en PostgreSQL
# Procesando green: 2025-08
# Archivo https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-08.parquet cargado en DataFrame
# Datos de green para 2025-08 cargados en PostgreSQL

# %% [markdown]
# ### Carga de taxi_zone

# %%
# cargar taxi zones
url_zones = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"
# Descargar archivo temporalmente
tmp_file = tempfile.NamedTemporaryFile(delete=False, suffix=".csv")
tmp_path = tmp_file.name
tmp_file.close()
r = requests.get(url_zones)
with open(tmp_path, "wb") as f:
    f.write(r.content)
df_zones = spark.read.csv(tmp_path, header=True, inferSchema=True)
print(f"Archivo {url_zones} cargado en DataFrame")


df_zones.write \
    .format("jdbc") \
    .options(**pgOptions) \
    .option("dbtable", "RAW.TAXI_ZONES") \
    .mode("overwrite") \
    .save()

print("Datos de taxi zones cargados en PostgreSQL")
os.remove(tmp_path)
# Out:
# Archivo https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv cargado en DataFrame
# Datos de taxi zones cargados en PostgreSQL
